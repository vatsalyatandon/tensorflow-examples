# %% [markdown]
# # Basic Classification of MNIST Fashion dataset using Keras

# %%
from __future__ import absolute_import, division, print_function
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.8.0

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#Scaling
train_images = train_images/255.0
test_images = test_images/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
#Building the model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

#Flatten formats 2D 28x28 into 1D 784
#Dense (1) fully connected 128 nodes
#Dense (2) 10 node softmax layer

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#Loss function to steer the model in the right direction by miniizing this function
#Optimizer - how the model is updated
#To monitor the training and testing steps

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.4973 - acc: 0.8242
# Epoch 2/5
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.3737 - acc: 0.8651
# Epoch 3/5
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.3336 - acc: 0.8784
# Epoch 4/5
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.3089 - acc: 0.8861
# Epoch 5/5
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.2922 - acc: 0.8925

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 28us/step
# Test accuracy: 0.8749

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([1.18592889e-05, 1.63650697e-07, 1.19306762e-07, 1.19104634e-07,
#        9.28528698e-06, 3.84467840e-02, 5.51916446e-06, 4.54895720e-02,
#        3.90875766e-06, 9.16032732e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap = plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label], 100*np.max(predictions_array), class_names[true_label]), color=color)
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label, = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color='#777777')
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
plt.show()

# %%
plot_value_array(450, predictions, test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)
